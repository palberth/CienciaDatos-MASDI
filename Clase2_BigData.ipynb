# %% [markdown]
# <a href="https://colab.research.google.com/github/palberth/CienciaDatos-MASDI/blob/main/Clase2_BigData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importacion e instalacion de librerias

# %%
# !pip install --upgrade google-cloud-bigquery google-auth google-auth-oauthlib google-auth-httplib2

# %% [markdown]
# **Autenticación** **colab**

# %%
from google.colab import auth
auth.authenticate_user()
print("Autenticación exitosa")
# Out:
# Autenticación exitosa

# %% [markdown]
# Importar cliente BigQuery

# %%
from google.cloud import bigquery

# Reemplaza con tu ID de proyecto en GCP
PROJECT_ID = "bigdata-usta-1"
client = bigquery.Client(project=PROJECT_ID)

# %%
query = """
SELECT *
FROM `bigdata-usta-1.Data.dataprod`
"""

df = client.query(query).to_dataframe()
df.head()
# Out:
#    Product ID                                      Product Title  \
# 0           1                    apple iphone 8 plus 64gb silver
# 1           2                apple iphone 8 plus 64 gb spacegrau
# 2           3  apple mq8n2b/a iphone 8 plus 64gb 5.5 12mp sim...
# 3           4                apple iphone 8 plus 64gb space grey
# 4           5  apple iphone 8 plus gold 5.5 64gb 4g unlocked ...
#
#     Merchant ID   Cluster ID             Cluster Label   Category ID  \
# 0             1            1  Apple iPhone 8 Plus 64GB          2612
# 1             2            1  Apple iPhone 8 Plus 64GB          2612
# 2             3            1  Apple iPhone 8 Plus 64GB          2612
# 3             4            1  Apple iPhone 8 Plus 64GB          2612
# 4             5            1  Apple iPhone 8 Plus 64GB          2612
#
#    Category Label
# 0   Mobile Phones
# 1   Mobile Phones
# 2   Mobile Phones
# 3   Mobile Phones
# 4   Mobile Phones
